# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Warnings ignored to reduce output; warnings come from shap package that parameter was set automatically; remove to check for other warnings (e.g. package out of date)
import warnings
warnings.simplefilter('ignore')

# Set random seed 
RSEED = 100

# %%
# Load Training Data

train_data = pd.read_csv("../00_Data_Sets/1_mio_dataset_2010_2014.csv");
test_data = pd.read_csv("../00_Data_Sets/100_k_dataset_2015.csv");

# %%
# Load Input Data

passenger_outlier = pd.read_csv("../01_Synthetic Data/02_Passenger Count/passenger count_outlier_predited_02.csv");
passenger_drift = pd.read_csv("../01_Synthetic Data/02_Passenger Count/passenger count_drift_total_predicted_03.csv");
distance_drift = pd.read_csv("../01_Synthetic Data/03_Distance/distance_drift_total_predicted_02.csv");
location_drift = pd.read_csv("../01_Synthetic Data/01_Location/location_drift_total_predicted_02.csv");
fare_amount_drift = pd.read_csv("../01_Synthetic Data/04_Fare Amount/fare-amount_drift_total_02.csv");
incoming_data_location_outlier = pd.read_csv("../01_Synthetic Data/01_Location/location_outlier_predicted_01.csv");
incoming_data_distance_outlier = pd.read_csv("../01_Synthetic Data/03_Distance/distance_drift_total_predicted_02.csv");

# %%
def monitor_drift_main_metrics(training_data, incoming_batch, start_index, end_index, batch_info, column, thresholds):
    batch_thresholds = thresholds[batch_info['name'].lower() + '_batch_drift']
    threshold = batch_thresholds['one_dim_drift_metric']
            
    if abs(incoming_batch.iloc[start_index:end_index,column].mean()) > abs((training_data.iloc[:,column].mean() * (1 + threshold))):
        print('[DRIFT][{} Window]: Upwards Data Drift detected!. ({} AVG: {})\t(Index: {})'.format(batch_info['name'], training_data.columns[column], incoming_batch.iloc[start_index:end_index,column].mean(), end_index))
        
    if abs(incoming_batch.iloc[start_index:end_index,column].quantile(0.25)) > abs((training_data.iloc[:,column].quantile(0.25) * (1 + threshold))):
        print('[DRIFT][{} Window]: Upwards Data Drift detected! ({} 25%-Quantile: {})\t(Index: {})'.format(batch_info['name'], training_data.columns[column], incoming_batch.iloc[start_index:end_index,column].mean(), end_index))
        
    if abs(incoming_batch.iloc[start_index:end_index,column].quantile(0.75)) > abs((training_data.iloc[:,column].quantile(0.75) * (1 + threshold))):
        print('[DRIFT][{} Window]: Upwards Data Drift detected! ({} 75%-Quantile: {})\t(Index: {})'.format(batch_info['name'], training_data.columns[column], incoming_batch.iloc[start_index:end_index,column].mean(), end_index))
        
    if abs(incoming_batch.iloc[start_index:end_index,column].mean()) < abs((training_data.iloc[:,column].mean() * (1 - threshold))):
        print('[DRIFT][{} Window]: Downwards Data Drift detected! ({} AVG: {})\t(Index: {})'.format(batch_info['name'], training_data.columns[column], incoming_batch.iloc[start_index:end_index,column].mean(), end_index))
        
    if abs(incoming_batch.iloc[start_index:end_index,column].quantile(0.25)) < abs((training_data.iloc[:,column].quantile(0.25) * (1 - threshold))):
        print('[DRIFT][{} Window]: Downwards Data Drift detected! ({} 25%-Quantile: {})\t(Index: {})'.format(batch_info['name'], training_data.columns[column], incoming_batch.iloc[start_index:end_index,column].mean(), end_index))
        
    if abs(incoming_batch.iloc[start_index:end_index,column].quantile(0.75)) < abs((training_data.iloc[:,column].quantile(0.75) * (1 - threshold))):
        print('[DRIFT][{} Window]: Downwards Data Drift detected! ({} 75%-Quantile: {})\t(Index: {})'.format(batch_info['name'], training_data.columns[column], incoming_batch.iloc[start_index:end_index,column].mean(), end_index))
        
    return incoming_batch.iloc[start_index:end_index,column].mean();    

        
from math import log2

def kl_divergence(p, q):
    return sum(p[i] * log2(p[i]/q[i]) for i in range(len(p)))

        
def monitor_drift_kl_divergence(training_data, incoming_batch, start_index, end_index, batch_info, column, thresholds):
    batch_thresholds = thresholds[batch_info['name'].lower() + '_batch_drift']
    threshold = batch_thresholds['one_dim_drift_kl_divergence']
    
    # Filter out zero values in datasets
    batch_df = incoming_batch[incoming_batch.iloc[:,column] != 0]
    train_df = training_data[training_data.iloc[:,column] != 0]
    
    # Filter out negative values in dataset, if mean is positive (= remove negative outliers)
    if batch_df.iloc[:,column].mean() > 0:
        batch_df = batch_df[batch_df.iloc[:,column] > 0]
        
    batch_df = batch_df.reset_index()
    train_df = train_df.reset_index()
    batch_df = batch_df.drop('index', axis=1)
    train_df = train_df.drop('index', axis=1)
    batch = batch_df.iloc[start_index:end_index,column]
    batch = batch.reset_index()
    batch = batch.drop('index', axis=1)
    batch = batch.iloc[:,0]
    train = train_df.iloc[:,column]
    
    divergence_score = kl_divergence(batch, train);
    
    if divergence_score > threshold:
        print('[DRIFT][{} Window]: KL-Divergence detected! ({} Divergence: {})\t(Index: {})'.format(batch_info['name'], batch_df.columns[column], divergence_score, end_index))        
        
    return divergence_score;
        

from scipy.stats import wasserstein_distance

def monitor_drift_wasserstein_distance(training_data, incoming_batch, start_index, end_index, batch_info, column, thresholds):
    batch_thresholds = thresholds[batch_info['name'].lower() + '_batch_drift']
    threshold = batch_thresholds['one_dim_drift_wasserstein']
    
    batch = incoming_batch.iloc[start_index:end_index, column]
    train = training_data.iloc[:, column]
    wasserstein_dist = wasserstein_distance(batch, train);
    
    if wasserstein_dist > threshold:
        print('[DRIFT][{} Window]: Wasserstein Distance detected! ({} Distance: {})\t(Index: {})'.format(batch_info['name'], incoming_batch.columns[column], wasserstein_dist, end_index))
        
    return wasserstein_dist;
        

import statistics

def monitor_drift_pairwise_correlations(training_data, incoming_batch, start_index, end_index, batch_info, input_columns, train_pairwise_correlations, thresholds, dash_metrics):
    batch_thresholds = thresholds[batch_info['name'].lower() + '_batch_drift']
    threshold = batch_thresholds['one_dim_drift_correlations']
    is_first_batch = False;
    if(incoming_batch.shape[0] == batch_info['size']):
        is_first_batch = True;
    
    batch_pairwise_correlations = get_pairwise_correlations(incoming_batch.iloc[start_index:end_index,:], input_columns);
    
    for column in input_columns:
        temp_correlations = [];
        for key in train_pairwise_correlations:
            temp_columns = key.split(" <> ");
            for metric in range(0,1):
                distance = abs((train_pairwise_correlations[key][metric] - batch_pairwise_correlations[key][metric]))
                if distance > abs((train_pairwise_correlations[key][metric] * threshold)):
                    print('[DRIFT][{} Window]: Pairwise Correlation Drift detected: {}!\t(Index: {})'.format(batch_info['name'], key, end_index))
            if train_data.columns[column] in temp_columns:
                temp_correlations.append(batch_pairwise_correlations[key][0])
        dash_metrics[train_data.columns[column]]["pairwise correlation"].append(statistics.mean(temp_correlations))
        if is_first_batch:
            dash_metrics[train_data.columns[column]]["pairwise correlation"].append(statistics.mean(temp_correlations))
        
    return dash_metrics;
                    
    
def prepare_incoming_batch(data, start_index, end_index):
    # Remove fare-bin values with less occurences than 3; Avoid error in split data set
    df = data.iloc[start_index:end_index,:]
    df = df[df.groupby('fare-bin')['fare-bin'].transform(len) > 3]
    return df
    
def monitor_feature_importances(training_data, incoming_batch, start_index, end_index, batch_info, input_columns, feature_importances, thresholds, dash_metrics):
    batch_thresholds = thresholds[batch_info['name'].lower() + '_batch_drift']
    threshold = batch_thresholds['one_dim_drift_feature_importances']
    is_first_batch = False;
    if(incoming_batch.shape[0] == batch_info['size']):
        is_first_batch = True;
    
    incoming_batch = prepare_incoming_batch(incoming_batch, start_index, end_index);
  
    rf = get_rf(incoming_batch, input_columns);
    batch_feature_importance_list = rf.feature_importances_
    train_feature_importance_list = feature_importances
    feature_count = len(batch_feature_importance_list)
    
    for index in range(0, feature_count):
        if batch_feature_importance_list[index] > (train_feature_importance_list[index] * (1 + threshold)):
            print('[DRIFT][{} Window]: Feature Importance Drift detected for {}!\t(Index: {})'.format(batch_info['name'], incoming_batch.columns[input_columns[index]], end_index))
            
        if batch_feature_importance_list[index] < (train_feature_importance_list[index] / (1 + threshold)):
            print('[DRIFT][{} Window]: Feature Importance Drift detected for {}!\t(Index: {})'.format(batch_info['name'], incoming_batch.columns[input_columns[index]], end_index))
            
        dash_metrics[train_data.columns[input_columns[index]]]['feature importances'].append(batch_feature_importance_list[index]);
        if is_first_batch:
            dash_metrics[train_data.columns[input_columns[index]]]['feature importances'].append(batch_feature_importance_list[index]);
    
    return dash_metrics;
            
            

def monitor_drift_shap(train_data_infos, incoming_batch, start_index, end_index, batch_info, column, shap, shap_index, thresholds):
    batch_thresholds = thresholds[batch_info['name'].lower() + '_batch_drift']
    threshold = batch_thresholds['one_dim_drift_shap']
    shap_mean = train_data_infos['shap']['mean'][shap_index]

    # SHAP Mean
    if shap[1][shap_index] < (shap_mean - (abs(shap_mean * threshold))):
        print('[DRIFT][{} Window]: Downwards Shap Drift detected for {}!\t(Index: {})'.format(batch_info['name'], train_data.columns[column], end_index));    
        print('batch: {}, train: {}'.format(shap[1][shap_index], (shap_mean - (shap_mean * threshold))))
        
    # SHAP Mean
    if shap[1][shap_index] > (shap_mean + (abs(shap_mean * threshold))):
        print('[DRIFT][{} Window]: Upwards Shap Drift detected for {}!\t(Index: {})'.format(batch_info['name'], train_data.columns[column], end_index));            
        print('batch: {}, train: {}'.format(shap[1][shap_index], (shap_mean - (shap_mean * threshold))))
        
    return shap[1][shap_index];

def monitor_drift_one_dimension(training_data, train_data_infos, incoming_batch, start_index, end_index, batch_info, thresholds, dash_metrics):
    input_columns = train_data_infos['input_columns']
    output_columns = train_data_infos['output_columns']
    columns_to_use = np.concatenate((output_columns, input_columns), axis=0)
    train_pairwise_correlations = train_data_infos['correlation_pairs']
    shap = get_shap_feature_importances(incoming_batch.iloc[start_index:end_index,:], train_data_infos['rf'], train_data_infos['input_columns'], thresholds)
    shap_index = 0
    is_first_batch = False;
    if(incoming_batch.shape[0] == batch_info['size']):
        is_first_batch = True;
    
    batch_metrics = []
    
    for column in columns_to_use:
        dash_metric_mean = monitor_drift_main_metrics(training_data, incoming_batch, start_index, end_index, batch_info, column, thresholds);
        dash_metrics[train_data.columns[column]]['mean'].append(dash_metric_mean)
        dash_metric_kl_divergence = monitor_drift_kl_divergence(training_data, incoming_batch, start_index, end_index, batch_info, column, thresholds);
        dash_metrics[train_data.columns[column]]['kl_divergence'].append(dash_metric_kl_divergence)
        dash_metric_wasserstein = monitor_drift_wasserstein_distance(training_data, incoming_batch, start_index, end_index, batch_info, column, thresholds);
        dash_metrics[train_data.columns[column]]['wasserstein'].append(dash_metric_wasserstein)
        
        if is_first_batch:
            dash_metrics[train_data.columns[column]]['mean'].append(dash_metric_mean)
            dash_metrics[train_data.columns[column]]['kl_divergence'].append(dash_metric_kl_divergence)
            dash_metrics[train_data.columns[column]]['wasserstein'].append(dash_metric_wasserstein)
        
        if column in input_columns:
            dash_metric_shap = monitor_drift_shap(train_data_infos, incoming_batch, start_index, end_index, batch_info, column, shap, shap_index, thresholds);
            dash_metrics[train_data.columns[column]]['shap'].append(dash_metric_shap);
            if is_first_batch:
                dash_metrics[train_data.columns[column]]['shap'].append(dash_metric_shap);
            shap_index = shap_index + 1
        
           
    dash_metrics = monitor_drift_pairwise_correlations(training_data, incoming_batch, start_index, end_index, batch_info, input_columns, train_pairwise_correlations, thresholds, dash_metrics);
    dash_metrics = monitor_feature_importances(training_data, incoming_batch, start_index, end_index, batch_info, input_columns, train_data_infos['rf_feature_importances'], thresholds, dash_metrics);
    return dash_metrics;
    
def monitor_drift_multi_dimensions(training_data, train_data_infos, incoming_batch, start_index, end_index, batch_info, thresholds, dash_metrics):
    input_columns = train_data_infos['input_columns'];
    output_columns = train_data_infos['output_columns'];
    pca_model = train_data_infos['pca_model'];
    threshold = thresholds['multi_dim_outlier']
    is_first_batch = False;
    if(incoming_batch.shape[0] == batch_info['size']):
        is_first_batch = True;
    
    incoming_batch_filtered = get_data_filtered(incoming_batch, input_columns);
    incoming_batch_transformed = transform_pca(pca_model, incoming_batch_filtered);
    distances = calculate_euclidean_distances(incoming_batch_transformed, input_columns);
    distances_metrics = get_distance_metrics(distances, thresholds);
    
    if distances_metrics['mean'] > train_data_infos['distance_metrics']['mean'] * (1 + threshold):
        print('[DRIFT][{} Window]: Multi-Dimensional Upwards Mean Drift Detected! Distance: {}\t\t\t(Index: {})'.format(batch_info['name'], distances_metrics['maximum'], end_index));
        
    if distances_metrics['mean'] < train_data_infos['distance_metrics']['mean'] * (1 - threshold):
        print('[DRIFT][{} Window]: Multi-Dimensional Downwards Mean Drift Detected! Distance: {}\t\t\t(Index: {})'.format(batch_info['name'], distances_metrics['maximum'], end_index));
        
    if distances_metrics['first_quarter'] < train_data_infos['distance_metrics']['first_quarter'] * (1 - threshold):
        print('[DRIFT][{} Window]: Multi-Dimensional 1st Quarter Downwards Drift Detected! Distance: {}\t\t\t(Index: {})'.format(batch_info['name'], distances_metrics['first_quarter'], end_index));
        
    if distances_metrics['third_quarter'] > (train_data_infos['distance_metrics']['third_quarter'] * (1 + threshold)):
        print('batch: {}, train: {}, train+threshold: {}'.format(distances_metrics['third_quarter'], train_data_infos['distance_metrics']['third_quarter'], (train_data_infos['distance_metrics']['third_quarter'] * (1 - threshold))))
        print('[DRIFT][{} Window]: Multi-Dimensional 3rd Quarter Upwards Drift Detected! Distance: {}\t\t\t(Index: {})'.format(batch_info['name'], distances_metrics['third_quarter'], end_index));
        
    dash_metrics['multidimension euclidean distance'].append(distances_metrics['mean']);
    if is_first_batch:
        dash_metrics['multidimension euclidean distance'].append(distances_metrics['mean']);
    return dash_metrics;
        
        
def monitor_batch_drift(training_data, train_data_infos, incoming_batch, index, batch_info, thresholds, dash_metrics):
    batch_size = batch_info['size'];
    start_index = index - batch_size + 1;
    end_index = index;
    
    dash_metrics = monitor_drift_one_dimension(training_data, train_data_infos, incoming_batch, start_index, end_index, batch_info, thresholds, dash_metrics);
    return monitor_drift_multi_dimensions(training_data, train_data_infos, incoming_batch, start_index, end_index, batch_info, thresholds, dash_metrics);
    
def monitor_drift(training_data, train_data_infos, batch, step_sizes, index, row, batch_infos, thresholds, dash_metrics):
    # Add new sample to batch
    batch.loc[index] = row.values;
        
    if batch.shape[0] % step_sizes['small'] == 0 and batch.shape[0] > (step_sizes['small']):
        return monitor_batch_drift(training_data, train_data_infos, batch, index, batch_infos['small'], thresholds, dash_metrics);

    if batch.shape[0] % step_sizes['medium'] == 0:
        return monitor_batch_drift(training_data, train_data_infos, batch, index, batch_infos['medium'], thresholds, dash_metrics);

    if batch.shape[0] % step_sizes['large'] == 0:
        return monitor_batch_drift(training_data, train_data_infos, batch, index, batch_infos['large'], thresholds, dash_metrics);
    
    return -1;

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

def get_rf(data, columns):
    # Split data
    X_train, X_valid, y_train, y_valid = train_test_split(data, np.array(data['fare_amount']), 
                                                          stratify = data['fare-bin'], test_size=0.33,
                                                          random_state = RSEED)

    # Create the random forest        
    rf = RandomForestRegressor(n_estimators = 20, max_depth = 20, max_features = None, oob_score = True, 
                                bootstrap = True, verbose = 1, n_jobs = -1)

    # Train random forest
    column_list = []
    for column in columns:
        column_list.append(train_data.columns[column])
        
    rf.fit(X_train[column_list], y_train)
    
    return rf

# %%
# SAVE RF
'''
from sklearn.externals import joblib

input_columns = [3, 4, 5, 6, 7, 12, 13, 14]
rf = get_rf(train_data, input_columns)

filename = 'rf.sav'
joblib.dump(rf, filename);
'''
# Out:
# "\nfrom sklearn.externals import joblib\n\ninput_columns = [3, 4, 5, 6, 7, 12, 13, 14]\nrf = get_rf(train_data, input_columns)\n\nfilename = 'rf.sav'\njoblib.dump(rf, filename);\n"

# %%
def get_avg_samples_per_day(data):
    # TODO: More elegant solution possible?
    df = pd.DataFrame();
    df['pickup_datetime'] = train_data['pickup_datetime']
    df['count'] = 1
    df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
    df.index = df['pickup_datetime'] 
    df = df.resample('D').sum()
    df = df[df['count'] != 0]
    return df['count'].mean()

def get_batch_infos(data):
    batch_size_day = get_avg_samples_per_day(data);
    batch_size_week = batch_size_day * 7;
    batch_size_month = batch_size_day * 30;
    
    batch_sizes = {
        'small': {'size': int(batch_size_day), 'name': 'Small'},
        'medium': {'size': int(batch_size_week), 'name': 'Medium'},
        'large': {'size': int(batch_size_month), 'name': 'Large'},        
    }
    
    return batch_sizes;

def get_step_sizes(batch_infos):
    step_sizes = {
        'small': (batch_infos['small']['size'] / 2),
        'medium': (batch_infos['medium']['size'] / 2),
        'large': (batch_infos['large']['size'] / 2) 
    }
    return step_sizes;

def get_data_filtered(data, columns_to_use):
    data_filtered = pd.DataFrame()
    i = 0

    # Filter Input Columns
    for column in columns_to_use:
        data_filtered.insert(i, data.columns[column], data.iloc[:,column])
        i = i + 1
        
    return data_filtered;

def apply_pca(train_data_filtered):
    pca_model = get_pca_model(train_data_filtered);
    return pca_model, transform_pca(pca_model, train_data_filtered);

def get_pca_model(train_data_filtered):
    from sklearn.decomposition import PCA
    
    pca = PCA(whiten=True)
    return pca.fit(train_data_filtered)

def transform_pca(pca_model, train_data_filtered):
    from sklearn.decomposition import PCA
    
    return pca_model.transform(train_data_filtered)

def get_zero_vector(columns_to_use):
    number_of_dimensions = len(columns_to_use)
    return np.zeros((number_of_dimensions)*1)

def calculate_euclidean_distance(sample, zero_vector):
    from scipy.spatial import distance
    
    return distance.euclidean(sample, zero_vector)

def calculate_euclidean_distances(transformed_data, columns_to_use):
    from scipy.spatial import distance
    
    zero_vector = get_zero_vector(columns_to_use);
    
    index = 0
    distances = np.ndarray(shape=(np.size(transformed_data,0),1))

    # Create distances to zero vector
    for sample in transformed_data:
        distances[index] = calculate_euclidean_distance(transformed_data[index], zero_vector);
        index = index + 1
        
    return distances;

def get_pairwise_correlations(data, input_columns):
    
    from scipy.stats.stats import pearsonr
    import itertools
    
    pairwise_correlations = {}

    for column_a, column_b in itertools.combinations(input_columns, 2):
        correlation = pearsonr(data.iloc[:,column_a], data.iloc[:,column_b])
        pairwise_correlations['{} <> {}'.format(data.columns[column_a], data.columns[column_b])] = correlation
        
    return pairwise_correlations

def get_shap_feature_importances(data, rf, input_columns, thresholds):
    import shap
    raw_threshold = thresholds['one_dim_outlier']
    threshold =     raw_threshold * 1000

    column_list = []
    for column in input_columns:
        column_list.append(train_data.columns[column])

    explainer = shap.TreeExplainer(rf, data=None);
    shap_values = explainer.shap_values(data[column_list]);

    shap_values_lower_quantile = []
    shap_values_mean = []
    shap_values_upper_quantile = []

    for column in range(0, len(input_columns)):    
        shap_values_lower_quantile.append(np.percentile(shap_values[:,column], threshold))
        shap_values_mean.append(shap_values[:,column].mean())
        shap_values_upper_quantile.append(np.percentile(shap_values[:,column], (100 - threshold)))
        
    shap = [shap_values_lower_quantile, shap_values_mean, shap_values_upper_quantile]
    return shap
    

def get_distance_metrics(distances, thresholds):
    
    raw_threshold = thresholds['multi_dim_outlier']
    threshold = raw_threshold * 100
    
    distance_metrics = {
        'minimum': distances.min(),
        'lower_threshold_percentile': np.percentile(distances, threshold),
        'first_quarter': np.percentile(distances, 25),
        'mean': distances.mean(),
        'third_quarter': np.percentile(distances, 75),
        'upper_threshold_percentile': np.percentile(distances, (100 - threshold)),
        'maximum': distances.max()
    }    
        
    return distance_metrics
    

def get_train_data_infos(distances, correlation_pairs, shap, rf, input_columns, output_columns, pca_model, thresholds):
    
    train_data_infos = {
        'input_columns': input_columns,
        'output_columns': output_columns,
        'pca_model': pca_model,
        'rf': rf,
        'rf_feature_importances': rf.feature_importances_,
        'shap': {
            'lower_threshold_percentile': shap[0],
            'mean': shap[1],
            'upper_threshold_percentile': shap[2]
        },
        'correlation_pairs': correlation_pairs,
        'distance_metrics': get_distance_metrics(distances, thresholds)
    }
    
    return train_data_infos;

def generate_train_data_infos(train_data, input_columns, output_columns, thresholds):
    # +++ REMOVE: Only for testing purposes +++    
    from sklearn.externals import joblib
    rf = joblib.load('rf.sav')
    test = {
        'input_columns': input_columns,
        'output_columns': output_columns,
        'pca_model': get_pca_model(get_data_filtered(train_data, input_columns)),
        'rf': rf,
        'rf_feature_importances': rf.feature_importances_,
        'shap': {
            'lower_threshold_percentile': [-2.528580313995101, -1.7864965686783245, -1.5736475393454952, -3.1326455478959168, -0.6049921796435059, -1.4670753181848482, -10.497608109368514, -1.170986733676531],
            'mean': [0.05859532547100909, 0.1150723753541944, 0.2375574423112044, -0.21863576089415065, 0.0049141129696212635, 0.18305498308684381, -0.6148760801903526, 0.16000324432733556],
            'upper_threshold_percentile': [7.925407442096883, 4.635143181597266, 19.453888955544727, 4.732747057367445, 0.4361906308296687, 6.485159131158373, 40.0529875893241, 6.800010400410237]
        },
        'correlation_pairs': get_pairwise_correlations(train_data, input_columns),
        'distance_metrics': {
            'minimum': 0.7249817600534729, 
            'lower_threshold_percentile': 0.7550153949050724,
            'first_quarter': 1.0764902427267036,
            'mean': 1.922411839793231,
            'third_quarter': 2.200820905397247,
            'upper_threshold_percentile': 10.6967040765229, 
            'maximum': 58.320576749831
        }
    }
    return test
    # +++ REMOVE: Only for testing purposes +++

    train_data_filtered = get_data_filtered(train_data, input_columns);
    pca_model, transformed_data = apply_pca(train_data_filtered);
    distances = calculate_euclidean_distances(transformed_data, input_columns);
    correlation_pairs = get_pairwise_correlations(train_data, input_columns);
    rf = get_rf(train_data, input_columns);
    shap = get_shap_feature_importances(train_data, rf, input_columns, thresholds);
    
    return get_train_data_infos(distances, correlation_pairs, shap, rf, input_columns, output_columns, pca_model, thresholds);

# %%
def monitor_outliers_one_dimension(train_data, train_data_infos, incoming_sample, index, thresholds):
    
    threshold = thresholds['one_dim_outlier']
    input_columns = train_data_infos['input_columns']
    output_columns = train_data_infos['output_columns']
    columns_to_use = np.concatenate((output_columns, input_columns), axis=0) 
    shap = get_shap_feature_importances(pd.DataFrame(incoming_sample).transpose(), train_data_infos['rf'], input_columns, thresholds)
    shap_index = 0
    
    for column in columns_to_use:
            
            if incoming_sample[column] > train_data.iloc[:,column].max():
                print('[OUTLIER] MAX Outlier Detected! {}: {}\t\t\t(Index: {})'.format(train_data.columns[column], incoming_sample[column], index));

            elif incoming_sample[column] > train_data.iloc[:,column].quantile(1 - threshold):
                print('[POT. OUTLIER] Potential MAX Outlier Detected! {}: {}\t\t\t(Index: {})'.format(train_data.columns[column], incoming_sample[column], index));

            if incoming_sample[column] < train_data.iloc[:,column].min():
                print('[OUTLIER] MIN Outlier Detected! {}: {}\t\t\t(Index: {})'.format(train_data.columns[column], incoming_sample[column], index));
                
            elif incoming_sample[column] < train_data.iloc[:,column].quantile(threshold):
                print('[POT. OUTLIER] Potential MIN Outlier Detected! {}: {}\t\t\t(Index: {})'.format(train_data.columns[column], incoming_sample[column], index));
            
            
            if column in input_columns:
            
                # SHAP Lower Percentile
                if shap[0][shap_index] < train_data_infos['shap']['lower_threshold_percentile'][shap_index]:
                    print('[POT. MIN OUTLIER] Potential Shap Outlier Detected! {}\t\t\t(Index: {})'.format(train_data.columns[column], index));

                # SHAP Upper Percentile
                if shap[2][shap_index] > train_data_infos['shap']['upper_threshold_percentile'][shap_index]:
                    print('[POT. MAX OUTLIER] Potential Shap Outlier Detected! {}\t\t\t(Index: {})'.format(train_data.columns[column], index));

                shap_index = shap_index + 1
            

    
def monitor_outliers_multi_dimensions(train_data, train_data_infos, incoming_sample, index):
    incoming_sample_df = pd.DataFrame(incoming_sample).transpose();
    incoming_sample_df_filtered = get_data_filtered(incoming_sample_df, train_data_infos['input_columns']);
    incoming_sample_df_transformed = transform_pca(train_data_infos['pca_model'], incoming_sample_df_filtered);
    distance = calculate_euclidean_distance(incoming_sample_df_transformed, get_zero_vector(train_data_infos['input_columns']));

    if distance > train_data_infos['distance_metrics']['maximum']:
        print('[OUTLIER] Multi-Dimensional Outlier Detected! Distance: {}\t\t\t(Index: {})'.format(distance, index));
        
    elif distance > train_data_infos['distance_metrics']['upper_threshold_percentile']:
        print('[POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: {}\t\t\t(Index: {})'.format(distance, index));

def monitor_outliers(train_data, train_data_infos, incoming_sample, index, thresholds):
    monitor_outliers_one_dimension(train_data, train_data_infos, incoming_sample, index, thresholds);
    monitor_outliers_multi_dimensions(train_data, train_data_infos, incoming_sample, index);

# %%
# Define desired thresholds

def get_thresholds():
    thresholds = {
        'one_dim_outlier': 0.001,
        'multi_dim_outlier': 0.5,
        'small_batch_drift': {
            'one_dim_drift_metric': 0.3,
            'one_dim_drift_kl_divergence': 6500,
            'one_dim_drift_wasserstein': 1.2,
            'one_dim_drift_correlations': 50,
            'one_dim_drift_feature_importances': 50,
            'one_dim_drift_shap': 5
        },
        'medium_batch_drift': {
            'one_dim_drift_metric': 0.1,
            'one_dim_drift_kl_divergence': 1000,
            'one_dim_drift_wasserstein': 0.25,
            'one_dim_drift_correlations': 20,
            'one_dim_drift_feature_importances': 20,
            'one_dim_drift_shap': 3          
        },
        'large_batch_drift': {
            'one_dim_drift_metric': 0.05,
            'one_dim_drift_kl_divergence': 500,
            'one_dim_drift_wasserstein': 0.2,
            'one_dim_drift_correlations': 15,
            'one_dim_drift_feature_importances': 15,
            'one_dim_drift_shap': 1           
        }
    }
    
    return thresholds;

# %%
# Needs to be configured individually

def prepare_data(data):
    prepared_data = data.copy()
    prepared_data['fare-bin'] = data.iloc[:,8].astype("category").cat.codes
    
    return prepared_data

# %%
def get_dict():
    return {
        "mean": [],
        "kl_divergence": [],
        "wasserstein": [],
        "shap": [],
        "feature importances": [],
        "pairwise correlation": []
    }

def get_dashboard_metrics(input_columns, output_columns):
    features_for_dashboard = {}
    all_columns = input_columns + output_columns
    
    for index in all_columns:
        features_for_dashboard[train_data.columns[index]] = get_dict()
        
    features_for_dashboard['multidimension euclidean distance'] = []
    
    return features_for_dashboard;

# %%
def monitor(train_data, incoming_data):
    # START: DEFINED BY USER
    input_columns = [3, 4, 5, 6, 7, 12, 13, 14]
    output_columns = [1, 8]
    dashboard_mode = False
    # END: DEFINED BY USER
    train_data = prepare_data(train_data);
    incoming_data = prepare_data(incoming_data);
    thresholds = get_thresholds();
    batch = pd.DataFrame(columns=incoming_data.columns);
    batch_infos = get_batch_infos(train_data);
    train_data_infos = generate_train_data_infos(train_data, input_columns, output_columns, thresholds);
    step_sizes = get_step_sizes(batch_infos);
    dash_metrics_raw = get_dashboard_metrics(input_columns, output_columns);
    dashboard_indices = [1]
    
    for index, row in incoming_data.iterrows():
        if index % 1000 == 0:
            print('------------------------ INDEX: {} ------------------------'.format(index))
        monitor_outliers(train_data, train_data_infos, row, index, thresholds);
        dash_metrics = monitor_drift(train_data, train_data_infos, batch, step_sizes, index, row, batch_infos, thresholds, dash_metrics_raw);
        
        if dashboard_mode and dash_metrics != -1:
            dashboard_indices.append(index)
            print_dashboard(dashboard_indices, dash_metrics, input_columns, output_columns);

# %%
from IPython.display import clear_output
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'


def print_dashboard(dashboard_indices, dash_metrics, input_columns, output_columns):    
    total_columns = input_columns + output_columns
    clear_output(wait=True)
    

    for column in total_columns:
        fig = plt.figure(figsize=(8, 6))
        fig.suptitle(train_data.columns[column], fontsize=16)        
        plt.plot(dashboard_indices,dash_metrics[train_data.columns[column]]['mean'], label="mean")
        plt.plot(dashboard_indices,dash_metrics['pickup_longitude']['kl_divergence'], label="kl_divergence")
        plt.plot(dashboard_indices,dash_metrics['pickup_longitude']['wasserstein'], label="wasserstein")
        plt.plot(dashboard_indices,dash_metrics['pickup_longitude']['shap'], label="shap")
        plt.plot(dashboard_indices,dash_metrics['pickup_longitude']['feature importances'], label="feature importances")
        plt.plot(dashboard_indices,dash_metrics['pickup_longitude']['pairwise correlation'], label="pairwise correlation")
        plt.legend(loc='upper left')
        # if len(dashboard_indices) > 5:
        #     plt.savefig('Dashboard-Charts/chart_column_{}.png'.format(column), dpi=300, transparent=True)

    fig = plt.figure(figsize=(8, 6))
    fig.suptitle('multidimensional', fontsize=16)        
    plt.plot(dashboard_indices,dash_metrics['multidimension euclidean distance'], label="euclidean distance")    
    plt.legend(loc='upper left')
    
    # if len(dashboard_indices) > 5:
    #     plt.savefig('Dashboard-Charts/chart_multidim.png', dpi=300, transparent=True)
        
    plt.show()

# %%
monitor(train_data, location_drift);
# Out:
# ------------------------ INDEX: 0 ------------------------
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_latitude: 40.887882232666016			(Index: 4)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 115)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 120)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 120)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 305)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.36305999755859375			(Index: 343)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.2629007645951818			(Index: 343)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 27.40050231658701			(Index: 343)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 12.049343616294971			(Index: 343)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 344)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 40.86755752563477			(Index: 424)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.3475189208984233			(Index: 440)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.2458510235458707			(Index: 440)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 24.076034903779558			(Index: 440)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 11.937218647778947			(Index: 621)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_longitude: -73.62210845947266			(Index: 631)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_latitude: 41.02389526367188			(Index: 631)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 631)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.495525360107429			(Index: 631)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.3504990597107201			(Index: 631)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! euclidean			(Index: 631)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 34.81891090248362			(Index: 631)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 631)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 16.13067721846217			(Index: 631)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 686)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 822)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [POT. OUTLIER] Potential MIN Outlier Detected! dropoff_longitude: -74.18255615234375			(Index: 965)
# [POT. OUTLIER] Potential MIN Outlier Detected! dropoff_longitude: -74.18158721923827			(Index: 997)
# ------------------------ INDEX: 1000 ------------------------
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 1212)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 1677)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.34459304809571023			(Index: 1706)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.25502846339118684			(Index: 1706)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 27.038184350321245			(Index: 1706)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 12.91668895448385			(Index: 1706)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 1722)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 1765)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 1823)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! pickup_latitude			(Index: 1929)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.71955108642578			(Index: 1938)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! pickup_longitude			(Index: 1938)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! pickup_latitude			(Index: 1938)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_longitude: -73.7195587158203			(Index: 1938)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 1938)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 11.670874228277823			(Index: 1938)
# ------------------------ INDEX: 2000 ------------------------
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2012)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! euclidean			(Index: 2012)
# [POT. OUTLIER] Potential MIN Outlier Detected! dropoff_longitude: -74.17822265625			(Index: 2039)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2039)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! euclidean			(Index: 2039)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 11.534161379957293			(Index: 2039)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2104)
# [DRIFT][Small Window]: Downwards Data Drift detected! (passenger_count 75%-Quantile: 1.4629324546952225)	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [DRIFT][Small Window]: Pairwise Correlation Drift detected: pickup_longitude <> passenger_count!	(Index: 2127)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 2258)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 2261)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2276)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.49712980324225			(Index: 2282)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.7928870969434172			(Index: 2282)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2282)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.7791178495648801			(Index: 2282)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 86.7231781569875			(Index: 2282)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 69.46614602542712			(Index: 2282)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.85166639941991			(Index: 2283)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.0238218818300884			(Index: 2283)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2283)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.016784641997748			(Index: 2283)
# [OUTLIER] MAX Outlier Detected! haversine: 170.157775149662			(Index: 2283)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 123.07800036569293			(Index: 2283)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 41.712558160740585			(Index: 2286)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2286)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.0963205203597184			(Index: 2286)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.9405256839044978			(Index: 2286)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 103.93638459606329			(Index: 2286)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 69.67758245263217			(Index: 2286)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.67295325305524			(Index: 2287)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! pickup_longitude			(Index: 2287)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2287)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.3605970093959528			(Index: 2287)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.3230587325451603			(Index: 2287)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 27.405856156611478			(Index: 2287)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 15.010647118875001			(Index: 2287)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.31072530753282			(Index: 2291)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.892574429922774			(Index: 2291)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2291)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.884533906325501			(Index: 2291)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.7708504353642165			(Index: 2291)
# [OUTLIER] MAX Outlier Detected! haversine: 281.97599520911115			(Index: 2291)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 144.2557052552919			(Index: 2291)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.47380188221099			(Index: 2293)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.33374406557415			(Index: 2293)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2293)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.1043803547498783			(Index: 2293)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.6706624347182597			(Index: 2293)
# [OUTLIER] MAX Outlier Detected! haversine: 182.04340978254035			(Index: 2293)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 108.10114212936801			(Index: 2293)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.29844654042688			(Index: 2294)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.790188220791			(Index: 2294)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2294)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.7450337641043694			(Index: 2294)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.661840663153853			(Index: 2294)
# [OUTLIER] MAX Outlier Detected! haversine: 268.785027376111			(Index: 2294)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 137.18347702764265			(Index: 2294)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.12438967513131			(Index: 2297)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2297)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.8729591102690792			(Index: 2297)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2297)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.864179376717892			(Index: 2297)
# [OUTLIER] MAX Outlier Detected! haversine: 157.16044192992808			(Index: 2297)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 113.59049104843795			(Index: 2297)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.39689844942437			(Index: 2298)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.52379461729278			(Index: 2298)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 59.9543296017219			(Index: 2298)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.60161356555035			(Index: 2299)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 43.13738425156011			(Index: 2299)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2299)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.8402293041738176			(Index: 2299)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.464260542416289			(Index: 2299)
# [OUTLIER] MAX Outlier Detected! haversine: 272.6099815675738			(Index: 2299)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 184.99046924252485			(Index: 2299)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -71.65776491660925			(Index: 2300)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2300)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.3254389713302004			(Index: 2300)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2300)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.310128262058872			(Index: 2300)
# [OUTLIER] MAX Outlier Detected! haversine: 194.72330636334382			(Index: 2300)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2300)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 141.72129141816058			(Index: 2300)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.441442963945			(Index: 2302)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2302)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.5616049791702409			(Index: 2302)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.5370732613660631			(Index: 2302)
# [OUTLIER] MAX Outlier Detected! haversine: 129.58135904958604			(Index: 2302)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 91.3895386187903			(Index: 2302)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.66318239707688			(Index: 2303)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2303)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3563984439875796			(Index: 2303)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2303)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.2846238048173395			(Index: 2303)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 108.39541256610269			(Index: 2303)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 69.96126662947628			(Index: 2303)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.90533054793038			(Index: 2304)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 41.74094764523143			(Index: 2304)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.959053071422161			(Index: 2304)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2304)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.2010705788627734			(Index: 2304)
# [OUTLIER] MAX Outlier Detected! haversine: 198.20724515478366			(Index: 2304)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 89.82147564829427			(Index: 2304)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.21072926252012			(Index: 2305)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2305)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.806875565360741			(Index: 2305)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2305)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.7733283641986406			(Index: 2305)
# [OUTLIER] MAX Outlier Detected! haversine: 149.56578040073268			(Index: 2305)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 104.63745595100322			(Index: 2305)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.54687045595792			(Index: 2308)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2308)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.449139370702241			(Index: 2308)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4314732627426998			(Index: 2308)
# [OUTLIER] MAX Outlier Detected! haversine: 120.74725030745633			(Index: 2308)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 85.51790767107238			(Index: 2308)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.46215669246794			(Index: 2309)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.507103077476685			(Index: 2309)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2309)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.2665040021962426			(Index: 2309)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.8242335598950297			(Index: 2309)
# [OUTLIER] MAX Outlier Detected! haversine: 199.4340297167287			(Index: 2309)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 121.13336764887818			(Index: 2309)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.69279921944542			(Index: 2310)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 41.71218501856519			(Index: 2310)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2310)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.318381770799455			(Index: 2310)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.509613607897179			(Index: 2310)
# [OUTLIER] MAX Outlier Detected! haversine: 223.3418616757149			(Index: 2310)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 99.37015378813597			(Index: 2310)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.175612597000864			(Index: 2311)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.6677720929267679			(Index: 2311)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2311)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.5478586624082544			(Index: 2311)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 60.15747186302453			(Index: 2311)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2311)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 35.30046033964668			(Index: 2311)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.31204371474732			(Index: 2313)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.18305188533442			(Index: 2313)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_latitude: 41.698935652509434			(Index: 2313)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.2159250133651938			(Index: 2313)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2313)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.7765912022698267			(Index: 2313)
# [OUTLIER] MAX Outlier Detected! haversine: 153.0430366313431			(Index: 2313)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 77.27986463590875			(Index: 2313)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.77616860934879			(Index: 2314)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2314)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2314)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 10.747960882804112			(Index: 2314)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.75119786943156			(Index: 2315)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.406497307948285			(Index: 2315)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.880229248087033			(Index: 2315)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.319796303855695			(Index: 2315)
# [OUTLIER] MAX Outlier Detected! haversine: 200.45406992250219			(Index: 2315)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 92.24253495784737			(Index: 2315)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.96675580815146			(Index: 2316)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.44182580436267			(Index: 2316)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.7080717051955863			(Index: 2316)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2316)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.0943003273690164			(Index: 2316)
# [OUTLIER] MAX Outlier Detected! haversine: 184.2195040316874			(Index: 2316)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 81.21298916648446			(Index: 2316)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.46624942929493			(Index: 2317)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2317)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.5218754181171761			(Index: 2317)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2317)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.5134503721768472			(Index: 2317)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 43.2999167074026			(Index: 2317)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 30.277466254823395			(Index: 2317)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.11218114453625			(Index: 2322)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2322)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.8919158403270233			(Index: 2322)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.8900475629599365			(Index: 2322)
# [OUTLIER] MAX Outlier Detected! haversine: 159.36896930263237			(Index: 2322)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 116.07923509909496			(Index: 2322)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.05867559410183			(Index: 2324)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2324)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.9254094889059844			(Index: 2324)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2324)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.9211165610863866			(Index: 2324)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 77.66720279632536			(Index: 2324)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 55.98514444245653			(Index: 2324)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.08426506350018			(Index: 2326)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2326)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3401015503165894			(Index: 2326)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2326)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.318702141525301			(Index: 2326)
# [OUTLIER] MAX Outlier Detected! haversine: 146.78549452642503			(Index: 2326)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 119.5956695449848			(Index: 2326)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.44245435721466			(Index: 2327)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2327)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.5305375861447177			(Index: 2327)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2327)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.509822914164789			(Index: 2327)
# [OUTLIER] MAX Outlier Detected! haversine: 127.28905789110131			(Index: 2327)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2327)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 91.11253966408562			(Index: 2327)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.36381362998671			(Index: 2328)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.44606773595551			(Index: 2328)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 62.95114459147553			(Index: 2328)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.683020843586284			(Index: 2329)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.193225158771831			(Index: 2329)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.0163236841762284			(Index: 2329)
# [OUTLIER] MAX Outlier Detected! haversine: 224.0309654031973			(Index: 2329)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 164.86419218321709			(Index: 2329)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -72.86660137145074			(Index: 2331)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 43.1442153531165			(Index: 2331)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2331)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.522059782447009			(Index: 2331)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.6463923134245295			(Index: 2331)
# [OUTLIER] MAX Outlier Detected! haversine: 282.3660661672968			(Index: 2331)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 155.61682708867727			(Index: 2331)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.98608359466806			(Index: 2333)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.478551877710345			(Index: 2333)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2333)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.721891805991497			(Index: 2333)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.6385962506642873			(Index: 2333)
# [OUTLIER] MAX Outlier Detected! haversine: 253.98995614812983			(Index: 2333)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 125.22877091879417			(Index: 2333)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.42183860925469			(Index: 2334)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.8035950949626451			(Index: 2334)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.6720370629356933			(Index: 2334)
# [OUTLIER] MAX Outlier Detected! haversine: 185.8499601128611			(Index: 2334)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 139.35105763215358			(Index: 2334)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.31495699272796			(Index: 2337)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2337)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.6837040485318298			(Index: 2337)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.680095414019636			(Index: 2337)
# [OUTLIER] MAX Outlier Detected! haversine: 141.68399265377766			(Index: 2337)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 102.8539507123703			(Index: 2337)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.66489394861281			(Index: 2340)
# [POT. MAX OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2340)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.2950479154008718			(Index: 2340)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2340)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.2906266508545732			(Index: 2340)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 108.79767944801736			(Index: 2340)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2340)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 79.5507832787563			(Index: 2340)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.05895900645207			(Index: 2342)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2342)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3258047095770564			(Index: 2342)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2342)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.3114719729105508			(Index: 2342)
# [OUTLIER] MAX Outlier Detected! haversine: 145.9854000355812			(Index: 2342)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 119.58850502610046			(Index: 2342)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.70138181866754			(Index: 2343)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2343)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.284080370053168			(Index: 2343)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2343)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.2600637080697332			(Index: 2343)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 106.25456556267099			(Index: 2343)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 74.30558829392577			(Index: 2343)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.66152586817478			(Index: 2344)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 43.15171493579914			(Index: 2344)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2344)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.7445568959935187			(Index: 2344)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.4251652257731418			(Index: 2344)
# [OUTLIER] MAX Outlier Detected! haversine: 268.74588320745585			(Index: 2344)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 188.13250274722634			(Index: 2344)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.16309919241727			(Index: 2350)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2350)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.4307688701516597			(Index: 2350)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.42293119555857706			(Index: 2350)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 47.07593516972328			(Index: 2350)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2350)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 37.64168351997962			(Index: 2350)
# [OUTLIER] MAX Outlier Detected! dropoff_latitude: 41.9342687527552			(Index: 2351)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.2184942166223962			(Index: 2351)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2351)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.1571494272274665			(Index: 2351)
# [OUTLIER] MAX Outlier Detected! haversine: 128.72696122791862			(Index: 2351)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 101.37387028873482			(Index: 2351)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.51801903031274			(Index: 2353)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.27080289579892			(Index: 2353)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2353)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.0573149628982885			(Index: 2353)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.16240499071754			(Index: 2353)
# [OUTLIER] MAX Outlier Detected! haversine: 214.01182562298538			(Index: 2353)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 106.99365594799907			(Index: 2353)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.1174129866323			(Index: 2354)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2354)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.8805728532114472			(Index: 2354)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2354)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.8716468633073825			(Index: 2354)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 73.50361429948134			(Index: 2354)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 52.266045411501075			(Index: 2354)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.07613325387156			(Index: 2355)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.65976706879579			(Index: 2355)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.24483275788019			(Index: 2355)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.1054326677751192			(Index: 2355)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2355)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.9518027856403529			(Index: 2355)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 105.22756642290041			(Index: 2355)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2355)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 94.38998787915861			(Index: 2355)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -72.77971769823094			(Index: 2359)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2359)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.1979129170034355			(Index: 2359)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2359)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.1938989963404647			(Index: 2359)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 100.66802582624555			(Index: 2359)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2359)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 72.84656500208968			(Index: 2359)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.67161528462084			(Index: 2362)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2362)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.3361934006818856			(Index: 2362)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2362)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.317981667730704			(Index: 2362)
# [OUTLIER] MAX Outlier Detected! haversine: 195.4414502696886			(Index: 2362)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 140.25660447981153			(Index: 2362)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 41.71944653462013			(Index: 2363)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.226480836377931			(Index: 2363)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.0285926999651325			(Index: 2363)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 113.3342835841465			(Index: 2363)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 72.43462530558114			(Index: 2363)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -72.83540532728959			(Index: 2364)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.631904499795425			(Index: 2364)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.9818972743124728			(Index: 2364)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4168699626805958			(Index: 2364)
# [OUTLIER] MAX Outlier Detected! haversine: 133.80425826519718			(Index: 2364)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 64.77968644926092			(Index: 2364)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.60914308033455			(Index: 2365)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3809569970608564			(Index: 2365)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.3689148142485297			(Index: 2365)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 115.45536602105896			(Index: 2365)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 82.45541037739098			(Index: 2365)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.318570234883424			(Index: 2367)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_longitude: -73.49424874992124			(Index: 2367)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.9532293586956726			(Index: 2367)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2367)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.686895130096737			(Index: 2367)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 71.15401875767118			(Index: 2367)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2367)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 37.02105491846703			(Index: 2367)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.65540397418118			(Index: 2368)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2368)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3398848746957626			(Index: 2368)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2368)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.3393852425778705			(Index: 2368)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 112.96696501460241			(Index: 2368)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 82.2092655176882			(Index: 2368)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.96342364734045			(Index: 2372)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.20248956941185			(Index: 2372)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.458590305616312			(Index: 2372)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.4780750883104727			(Index: 2372)
# [OUTLIER] MAX Outlier Detected! haversine: 232.55067062071944			(Index: 2372)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 111.6512236327381			(Index: 2372)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.535755567982			(Index: 2375)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2375)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.4517322249867348			(Index: 2375)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4435918550147295			(Index: 2375)
# [OUTLIER] MAX Outlier Detected! haversine: 121.72166269128815			(Index: 2375)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 87.6747634915703			(Index: 2375)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.11819271816577			(Index: 2378)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.322174713542815			(Index: 2378)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2378)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.429373383316495			(Index: 2378)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.9456733144217704			(Index: 2378)
# [OUTLIER] MAX Outlier Detected! haversine: 168.56515915663496			(Index: 2378)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 76.91074275002755			(Index: 2378)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.10331972436232			(Index: 2381)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.392429021809576			(Index: 2381)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2381)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.5658541399765509			(Index: 2381)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.1199674798791932			(Index: 2381)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 105.79428187892336			(Index: 2381)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 50.105399269050075			(Index: 2381)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -71.90512610005281			(Index: 2387)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2387)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.095877165328055			(Index: 2387)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2387)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.0615119704296627			(Index: 2387)
# [OUTLIER] MAX Outlier Detected! haversine: 173.7631656429948			(Index: 2387)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2387)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 123.82502194796096			(Index: 2387)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.64434138531803			(Index: 2388)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.386465128869254			(Index: 2388)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2388)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.997162958639116			(Index: 2388)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4974217568662376			(Index: 2388)
# [OUTLIER] MAX Outlier Detected! haversine: 134.27474330928572			(Index: 2388)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 60.10537969297141			(Index: 2388)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.00623297491392			(Index: 2389)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! pickup_latitude			(Index: 2389)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.3366696814568826			(Index: 2389)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.2544129404410231			(Index: 2389)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 27.269775597044887			(Index: 2389)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 15.005035634869907			(Index: 2389)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.7279267176376			(Index: 2392)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2392)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_latitude: 41.06896359749496			(Index: 2392)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.6676987768809113			(Index: 2392)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2392)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.658986119800906			(Index: 2392)
# [OUTLIER] MAX Outlier Detected! haversine: 184.67238114621483			(Index: 2392)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 157.63721586819278			(Index: 2392)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.02960777156233			(Index: 2395)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2395)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.935171128584152			(Index: 2395)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2395)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.9337868892634171			(Index: 2395)
# [OUTLIER] MAX Outlier Detected! haversine: 163.05282224274518			(Index: 2395)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2395)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 119.97086148862655			(Index: 2395)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.1314711599721			(Index: 2396)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2396)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.8697113961802287			(Index: 2396)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2396)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.8486105764115773			(Index: 2396)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 71.57294164250816			(Index: 2396)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 49.21779943315274			(Index: 2396)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.42812421189201			(Index: 2399)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2399)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.5355560554419725			(Index: 2399)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2399)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.5286252755099543			(Index: 2399)
# [OUTLIER] MAX Outlier Detected! haversine: 128.89015264263028			(Index: 2399)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 93.1103060162843			(Index: 2399)
# [OUTLIER] MAX Outlier Detected! dropoff_latitude: 42.5916266328433			(Index: 2400)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.970319259796426			(Index: 2400)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2400)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.8277441129765803			(Index: 2400)
# [OUTLIER] MAX Outlier Detected! haversine: 203.1613836458073			(Index: 2400)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2400)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 154.25162203401905			(Index: 2400)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.20748414314505			(Index: 2401)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2401)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.7816363402533781			(Index: 2401)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2401)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.7769811804367099			(Index: 2401)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 65.51136371347984			(Index: 2401)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 47.04581647531196			(Index: 2401)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.62559001110944			(Index: 2403)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.191403626012324			(Index: 2403)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2403)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.7952829142192925			(Index: 2403)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.398807982603672			(Index: 2403)
# [OUTLIER] MAX Outlier Detected! haversine: 204.10586777751976			(Index: 2403)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 104.69824891914693			(Index: 2403)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.58090100128417			(Index: 2406)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2406)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.860392425844708			(Index: 2406)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2406)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.8421167904722026			(Index: 2406)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 93.73222158274969			(Index: 2406)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2406)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 75.362260960256			(Index: 2406)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.44758688028921			(Index: 2407)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.766218574468624			(Index: 2407)
# [OUTLIER] MAX Outlier Detected! dropoff_latitude: 41.7569627513315			(Index: 2407)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.5634923681408992			(Index: 2407)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2407)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.1514232342426982			(Index: 2407)
# [OUTLIER] MAX Outlier Detected! haversine: 121.27075480465449			(Index: 2407)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 92.28887061285374			(Index: 2407)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.64080475267302			(Index: 2408)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2408)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3471789509402612			(Index: 2408)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2408)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.3433924931776784			(Index: 2408)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 113.26559337750577			(Index: 2408)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 82.12411486564852			(Index: 2408)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.20395799368978			(Index: 2411)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.41699610077101			(Index: 2411)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2411)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.477293630762865			(Index: 2411)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.8625020620515256			(Index: 2411)
# [OUTLIER] MAX Outlier Detected! haversine: 198.91753853588366			(Index: 2411)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 109.24742353492455			(Index: 2411)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.57771979838586			(Index: 2413)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.416378864944221			(Index: 2413)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4002564898402259			(Index: 2413)
# [OUTLIER] MAX Outlier Detected! haversine: 118.04253518983441			(Index: 2413)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 84.05919193968897			(Index: 2413)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.6660458332666			(Index: 2414)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2414)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3282664531103665			(Index: 2414)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2414)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.327660054792272			(Index: 2414)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 111.9293458542426			(Index: 2414)
# ...
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 40.866146102937776			(Index: 2686)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! pickup_latitude			(Index: 2686)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_latitude			(Index: 2686)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.5612185438448			(Index: 2687)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2687)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.4124905626005102			(Index: 2687)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2687)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4050108839283892			(Index: 2687)
# [OUTLIER] MAX Outlier Detected! haversine: 118.46306735751757			(Index: 2687)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 85.39768324920529			(Index: 2687)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.53647265868908			(Index: 2688)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.88284158269093			(Index: 2688)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2688)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.616651669363179			(Index: 2688)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.2061483023513904			(Index: 2688)
# [OUTLIER] MAX Outlier Detected! haversine: 243.2105263278978			(Index: 2688)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 158.07023914511876			(Index: 2688)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.0451377698802			(Index: 2689)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.60365830342271			(Index: 2689)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.7878830213354675			(Index: 2689)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.1123768089646147			(Index: 2689)
# [OUTLIER] MAX Outlier Detected! haversine: 187.80642514776423			(Index: 2689)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 84.19541893728724			(Index: 2689)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 41.93687481684425			(Index: 2693)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2693)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.1949314574692522			(Index: 2693)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2693)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.1926219913646616			(Index: 2693)
# [OUTLIER] MAX Outlier Detected! haversine: 132.7591122771263			(Index: 2693)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 109.91311007724292			(Index: 2693)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.90908334578128			(Index: 2697)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.605388229723076			(Index: 2697)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2697)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.86114558218398			(Index: 2697)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2697)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.196478643987816			(Index: 2697)
# [OUTLIER] MAX Outlier Detected! haversine: 193.6881900609823			(Index: 2697)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 87.17773872206402			(Index: 2697)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.46001274521149			(Index: 2698)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.66882104497137			(Index: 2698)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2698)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.498950359086052			(Index: 2698)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.49014795650655			(Index: 2698)
# [OUTLIER] MAX Outlier Detected! haversine: 252.30689073778683			(Index: 2698)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 128.98655338818887			(Index: 2698)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.58221797598978			(Index: 2700)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 41.974691598218385			(Index: 2700)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_longitude: -73.60598116240445			(Index: 2700)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.2600209467424222			(Index: 2700)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2700)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 1.2364861256800137			(Index: 2700)
# [OUTLIER] MAX Outlier Detected! haversine: 137.63094973049462			(Index: 2700)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 110.64003474637418			(Index: 2700)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.006337820569335			(Index: 2702)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.3553864350712883			(Index: 2702)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2702)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.272830045602355			(Index: 2702)
# [OUTLIER] MAX Outlier Detected! haversine: 141.54825525288783			(Index: 2702)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 107.2817838679613			(Index: 2702)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.9987919637486			(Index: 2703)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.20697185313538			(Index: 2703)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2703)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.4628414494453708			(Index: 2703)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.0512496315651463			(Index: 2703)
# [OUTLIER] MAX Outlier Detected! haversine: 175.70090417598976			(Index: 2703)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 84.67108700284982			(Index: 2703)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.44040086783978			(Index: 2704)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.01015067676064			(Index: 2704)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_longitude: -73.20351369281676			(Index: 2704)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.0044341560344776			(Index: 2704)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2704)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.8003606489999996			(Index: 2704)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 69.60995205142659			(Index: 2704)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 43.48671138301506			(Index: 2704)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -72.73767613987454			(Index: 2705)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.546629247595895			(Index: 2705)
# [OUTLIER] MAX Outlier Detected! dropoff_longitude: -72.52335969640465			(Index: 2705)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! passenger_count			(Index: 2705)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.0303472413587471			(Index: 2705)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2705)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.8437048068161728			(Index: 2705)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 92.59794433416843			(Index: 2705)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! haversine			(Index: 2705)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 72.40376041888794			(Index: 2705)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.7454819436297			(Index: 2707)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.30834010697949			(Index: 2707)
# [OUTLIER] MAX Outlier Detected! manhattan: 3.669844131482485			(Index: 2707)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2707)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.620438081232053			(Index: 2707)
# [OUTLIER] MAX Outlier Detected! haversine: 247.46130520731097			(Index: 2707)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 119.05534579989914			(Index: 2707)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.15552887683631			(Index: 2708)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2708)
# [OUTLIER] MAX Outlier Detected! manhattan: 1.8035317921089769			(Index: 2708)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2708)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.8022047663881684			(Index: 2708)
# [OUTLIER] MAX Outlier Detected! haversine: 151.940304904377			(Index: 2708)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 110.77258727022327			(Index: 2708)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -71.84253228778613			(Index: 2709)
# [POT. OUTLIER] Potential MAX Outlier Detected! dropoff_latitude: 40.89822387695313			(Index: 2709)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.192551482965825			(Index: 2709)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2709)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.0321836125664587			(Index: 2709)
# [OUTLIER] MAX Outlier Detected! haversine: 171.63535083425944			(Index: 2709)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 105.35567422610261			(Index: 2709)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.34305215453587			(Index: 2711)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.1863018356138			(Index: 2711)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2711)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.0655587936267563			(Index: 2711)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2711)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.7654129361929704			(Index: 2711)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 71.82358716167279			(Index: 2711)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 33.685173721244915			(Index: 2711)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.44215956157626			(Index: 2713)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.30265505134886			(Index: 2713)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2713)
# [OUTLIER] MAX Outlier Detected! dropoff_latitude: 43.11593912089197			(Index: 2713)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.3522036095293544			(Index: 2713)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2713)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.7406045870110958			(Index: 2713)
# [OUTLIER] MAX Outlier Detected! haversine: 155.0483517045644			(Index: 2713)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 110.14270479874165			(Index: 2713)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.41609677487209			(Index: 2715)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2715)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 0.5956067163388568			(Index: 2715)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2715)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.5615377608779953			(Index: 2715)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 47.442189991678745			(Index: 2715)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 29.855699637778407			(Index: 2715)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.52215813508236			(Index: 2718)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.84170086265389			(Index: 2718)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2718)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.5285080290852093			(Index: 2718)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.138801699575929			(Index: 2718)
# [OUTLIER] MAX Outlier Detected! haversine: 235.8943583748231			(Index: 2718)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 154.27366843711818			(Index: 2718)
# [OUTLIER] MAX Outlier Detected! pickup_longitude: -72.54769944145346			(Index: 2721)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2721)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.4582400421891182			(Index: 2721)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2721)
# [OUTLIER] MAX Outlier Detected! euclidean: 1.4203047885002844			(Index: 2721)
# [OUTLIER] MAX Outlier Detected! haversine: 119.75371660445215			(Index: 2721)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 82.46791321689425			(Index: 2721)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -72.71250951348652			(Index: 2722)
# [OUTLIER] MAX Outlier Detected! pickup_latitude: 42.23145114486238			(Index: 2722)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2722)
# [OUTLIER] MAX Outlier Detected! manhattan: 2.823087444364127			(Index: 2722)
# [OUTLIER] MAX Outlier Detected! euclidean: 2.0023151541165407			(Index: 2722)
# [OUTLIER] MAX Outlier Detected! haversine: 201.1898670475826			(Index: 2722)
# [OUTLIER] Multi-Dimensional Outlier Detected! Distance: 101.7228080902173			(Index: 2722)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_longitude: -73.22882880763352			(Index: 2723)
# [POT. OUTLIER] Potential MAX Outlier Detected! pickup_latitude: 41.42091358229558			(Index: 2723)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! dropoff_longitude			(Index: 2723)
# [POT. OUTLIER] Potential MAX Outlier Detected! manhattan: 1.4118380400429091			(Index: 2723)
# [POT. MIN OUTLIER] Potential Shap Outlier Detected! manhattan			(Index: 2723)
# [POT. OUTLIER] Potential MAX Outlier Detected! euclidean: 0.9984366123891946			(Index: 2723)
# [POT. OUTLIER] Potential MAX Outlier Detected! haversine: 98.00501908474537			(Index: 2723)
# [POT. OUTLIER] Potential Multi-Dimensional Outlier Detected! Distance: 48.053262161235885			(Index: 2723)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-fa4e7f303286> in <module>
# ----> 1 monitor(train_data, location_drift);
#
# <ipython-input-38-3e3e750ef892> in monitor(train_data, incoming_data)
#      18         if index % 1000 == 0:
#      19             print('------------------------ INDEX: {} ------------------------'.format(index))
# ---> 20         monitor_outliers(train_data, train_data_infos, row, index, thresholds);
#      21         dash_metrics = monitor_drift(train_data, train_data_infos, batch, step_sizes, index, row, batch_infos, thresholds, dash_metrics_raw);
#      22
#
# <ipython-input-28-eb27ae4f379f> in monitor_outliers(train_data, train_data_infos, incoming_sample, index, thresholds)
#      50
#      51 def monitor_outliers(train_data, train_data_infos, incoming_sample, index, thresholds):
# ---> 52     monitor_outliers_one_dimension(train_data, train_data_infos, incoming_sample, index, thresholds);
#      53     monitor_outliers_multi_dimensions(train_data, train_data_infos, incoming_sample, index);
#
# <ipython-input-28-eb27ae4f379f> in monitor_outliers_one_dimension(train_data, train_data_infos, incoming_sample, index, thresholds)
#       5     output_columns = train_data_infos['output_columns']
#       6     columns_to_use = np.concatenate((output_columns, input_columns), axis=0)
# ----> 7     shap = get_shap_feature_importances(pd.DataFrame(incoming_sample).transpose(), train_data_infos['rf'], input_columns, thresholds)
#       8     shap_index = 0
#       9
#
# <ipython-input-27-08da78f4aa93> in get_shap_feature_importances(data, rf, input_columns, thresholds)
#     107
#     108     explainer = shap.TreeExplainer(rf, data=None);
# --> 109     shap_values = explainer.shap_values(data[column_list]);
#     110
#     111     shap_values_lower_quantile = []
#
# /usr/local/lib/python3.7/site-packages/shap/explainers/tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity)
#     298                 self.model.max_depth, X, X_missing, y, self.data, self.data_missing, tree_limit,
#     299                 self.model.base_offset, phi, feature_perturbation_codes[self.feature_perturbation],
# --> 300                 output_transform_codes[transform], False
#     301             )
#     302         else:
#
# KeyboardInterrupt:
